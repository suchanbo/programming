# %% [markdown]
# <a href="https://colab.research.google.com/github/suchanbo/programming/blob/master/Isolation_Forest_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Isolation Forest Example**

# %%
# import the libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest
import warnings
warnings.filterwarnings("ignore")

# %%
# Load the dataset
df = pd.read_csv('Employee_Salary_Dataset.csv')
df.head(5)
# we will be selecting ID, Experience_Years, Age, Gender, Salary
df = df[['ID', 'Experience_Years', 'Age', 'Gender', 'Salary']]
# check how many records are there in the dataset
df.shape
# view all the records
df.head(5)
# Out:
#    ID  Experience_Years  Age  Gender  Salary
# 0   1                 5   28  Female  250000
# 1   2                 1   21    Male   50000
# 2   3                 3   23  Female  170000
# 3   4                 2   22    Male   25000
# 4   5                 1   17    Male   10000

# %%
# Select only salary for the isolation forest model test
df_salary = df[['Salary']]
df_salary.head(5)
# Out:
#    Salary
# 0  250000
# 1   50000
# 2  170000
# 3   25000
# 4   10000

# %%
# Instantiate the model and fit the data to it
model=IsolationForest(n_estimators=1000,max_samples='auto', contamination=float(0.3),max_features=1.0,random_state=0)
model.fit(df_salary[['Salary']])
# Out:
# IsolationForest(contamination=0.3, n_estimators=1000, random_state=0)

# %%
# Get the score and anomaly flag
df_salary['scores']=model.decision_function(df[['Salary']])
df_salary['anomaly']=model.predict(df[['Salary']])
# view the data
df_salary.sort_values(by=['Salary'])
# Out:
#       Salary    scores  anomaly
# 26      3000  0.146115        1
# 23      6000  0.181805        1
# 29      6100  0.182610        1
# 14      7500  0.185777        1
# 24      8900  0.190545        1
# 7       9000  0.190582        1
# 4      10000  0.184160        1
# 18     15000  0.171313        1
# 25     20000  0.167480        1
# 3      25000  0.166210        1
# 21     25000  0.166210        1
# 1      50000  0.129629        1
# 8      61500  0.130281        1
# 30     80000  0.124799        1
# 15     87000  0.116219        1
# 2     170000  0.078659        1
# 13    220100  0.092702        1
# 10    250000  0.108197        1
# 0     250000  0.108197        1
# 19    330000  0.031781        1
# 9     650000  0.010287        1
# 6     800000  0.036427        1
# 31    900000  0.051114        1
# 16    930000  0.039080        1
# 11   1400000 -0.037059       -1
# 32   1540000 -0.056923       -1
# 28   5000000 -0.037755       -1
# 5    5001000 -0.037755       -1
# 12   6000050 -0.044214       -1
# 20   6570000 -0.002572       -1
# 22   6845000 -0.005663       -1
# 34   7600000 -0.024863       -1
# 17   7900000 -0.040408       -1
# 33   9300000 -0.114575       -1
# 27  10000000 -0.164486       -1

# %%
# fetch all the anomalies
anomaly=df_salary.loc[df_salary['anomaly']==-1]
anomaly_index=list(anomaly.index)
anomaly.head(40).sort_values(by=['Salary'])
# Out:
#       Salary    scores  anomaly
# 11   1400000 -0.037059       -1
# 32   1540000 -0.056923       -1
# 28   5000000 -0.037755       -1
# 5    5001000 -0.037755       -1
# 12   6000050 -0.044214       -1
# 20   6570000 -0.002572       -1
# 22   6845000 -0.005663       -1
# 34   7600000 -0.024863       -1
# 17   7900000 -0.040408       -1
# 33   9300000 -0.114575       -1
# 27  10000000 -0.164486       -1

# %%
#merge the two dataframes
df_merged = pd.merge(df, df_salary, on=["Salary"])
df_merged.sort_values(by=['Salary'])
# Out:
#     ID  Experience_Years  Age  Gender    Salary    scores  anomaly
# 30  27                 1   18    Male      3000  0.146115        1
# 27  24                 1   21  Female      6000  0.181805        1
# 33  30                 2   21  Female      6100  0.182610        1
# 19  15                 2   23    Male      7500  0.185777        1
# 28  25                 4   23  Female      8900  0.190545        1
# 13   8                 2   21  Female      9000  0.190582        1
# 10   5                 1   17    Male     10000  0.184160        1
# 23  19                 2   21    Male     15000  0.171313        1
# 29  26                 3   22  Female     20000  0.167480        1
# 9   22                 4   26    Male     25000  0.166210        1
# 8   22                 4   26    Male     25000  0.166210        1
# 7    4                 2   22    Male     25000  0.166210        1
# 6    4                 2   22    Male     25000  0.166210        1
# 4    2                 1   21    Male     50000  0.129629        1
# 14   9                10   36  Female     61500  0.130281        1
# 34  31                10   34    Male     80000  0.124799        1
# 20  16                 4   27  Female     87000  0.116219        1
# 5    3                 3   23  Female    170000  0.078659        1
# 18  14                11   40    Male    220100  0.092702        1
# 0    1                 5   28  Female    250000  0.108197        1
# 1    1                 5   28  Female    250000  0.108197        1
# 2   11                 4   26  Female    250000  0.108197        1
# 3   11                 4   26  Female    250000  0.108197        1
# 24  20                10   36    Male    330000  0.031781        1
# 15  10                15   54  Female    650000  0.010287        1
# 12   7                19   54  Female    800000  0.036427        1
# 35  32                15   54    Male    900000  0.051114        1
# 21  17                10   34  Female    930000  0.039080        1
# 16  12                 6   29    Male   1400000 -0.037059       -1
# 36  33                20   55  Female   1540000 -0.056923       -1
# 32  29                19   54  Female   5000000 -0.037755       -1
# 11   6                25   62    Male   5001000 -0.037755       -1
# 17  13                14   39    Male   6000050 -0.044214       -1
# 25  21                15   54    Male   6570000 -0.002572       -1
# 26  23                 5   29    Male   6845000 -0.005663       -1
# 38  35                16   49    Male   7600000 -0.024863       -1
# 22  18                15   54  Female   7900000 -0.040408       -1
# 37  34                19   53  Female   9300000 -0.114575       -1
# 31  28                27   62  Female  10000000 -0.164486       -1

# %% [markdown]
# **Let's make predictions by passing an amount value and see how well the model predicts**

# %%
# Test your model
# Model returns 1 ==> The amount is within the expected salary range
# Model return -1 ==> The amount deviates from the expected salary range
model.predict([[10000000]])
# Out:
# array([-1])
